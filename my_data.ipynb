# %% [markdown]
# <a href="https://colab.research.google.com/github/aka-sa/Human_Centered_AI_Data/blob/main/my_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from datasets import load_dataset

ds = load_dataset("akansha2k2/human_centered_ai_dataset", split="train",  streaming=True)

# %%
data_list = []
for example in ds:
    data_list.append(example)

# Convert the list of dictionaries to a pandas DataFrame
dataset = pd.DataFrame(data_list)

print(dataset)
# Out:
#             ID                            Task  ... Efficiency Score User Satisfaction
# 0            1    Gesture-based Control System  ...            75.05                 2
# 1            2      Automated Content Creation  ...            82.12                 5
# 2            3    Gesture-based Control System  ...            25.03                 2
# 3            4    Gesture-based Control System  ...            96.61                 1
# 4            5      Automated Content Creation  ...            66.47                 4
# ...        ...                             ...  ...              ...               ...
# 499995  499996      Automated Content Creation  ...             8.37                10
# 499996  499997      Automated Content Creation  ...            85.96                 7
# 499997  499998    Gesture-based Control System  ...            95.13                 3
# 499998  499999      Automated Content Creation  ...            18.59                 6
# ...

# %%
dataset.head()
# Out:
#    ID                          Task  ... Efficiency Score User Satisfaction
# 0   1  Gesture-based Control System  ...            75.05                 2
# 1   2    Automated Content Creation  ...            82.12                 5
# 2   3  Gesture-based Control System  ...            25.03                 2
# 3   4  Gesture-based Control System  ...            96.61                 1
# 4   5    Automated Content Creation  ...            66.47                 4
#
# [5 rows x 12 columns]

# %%
# !pip install transformers pandas

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

model_name = "gpt2"
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
import pandas as pd

def create_pandas_dataframe_agent(model, tokenizer, df, verbose=False):
    def query_agent(query):
        # Convert query to input format
        inputs = tokenizer(query, return_tensors="pt")

        # Generate response
        outputs = model.generate(inputs["input_ids"], max_length=50)
        response = tokenizer.decode(outputs[0], skip_special_tokens=True)

        if verbose:
            print(f"Query: {query}")
            print(f"Response: {response}")

        return response

    return query_agent

# %%
import pandas as pd

def create_pandas_dataframe_agent(model, tokenizer, df, verbose=False):
    def query_agent(query):
        # Convert query to input format
        inputs = tokenizer(query, return_tensors="pt")

        # Generate response
        outputs = model.generate(inputs["input_ids"], max_length=50)
        response = tokenizer.decode(outputs[0], skip_special_tokens=True)

        if verbose:
            print(f"Query: {query}")
            print(f"Response: {response}")

        return response

    return query_agent

# %%
# Load your dataset
df = pd.read_csv("human_centered_ai_dataset.csv").fillna(value=0)

# Create the agent
agent = create_pandas_dataframe_agent(model, tokenizer, df, verbose=True)

# Use the agent
response = agent("how many rows are there in the dataset?")
print(response)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token.As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Query: how many rows are there in the dataset?
# Response: how many rows are there in the dataset?
#
# The answer is that there are many rows in the dataset. The dataset is not a single row. It is a collection of rows.
#
# The dataset is a collection of rows. The dataset
# how many rows are there in the dataset?
#
# The answer is that there are many rows in the dataset. The dataset is not a single row. It is a collection of rows.
#
# The dataset is a collection of rows. The dataset

# %%
# CSV_PROMPT_PREFIX = """
# First set the pandas display options to show all the columns,
# get the column names, then answer the question.
# """

# CSV_PROMPT_SUFFIX = """
# - **ALWAYS** before giving the Final Answer, try another method.
# Then reflect on the answers of the two methods you did and ask yourself
# if it answers correctly the original question.
# If you are not sure, try another method.
# - If the methods tried do not give the same result,reflect and
# try again until you have two methods that have the same result.
# - If you still cannot arrive to a consistent result, say that
# you are not sure of the answer.
# - If you are sure of the correct answer, create a beautiful
# and thorough response using Markdown.
# - **DO NOT MAKE UP AN ANSWER OR USE PRIOR KNOWLEDGE,
# ONLY USE THE RESULTS OF THE CALCULATIONS YOU HAVE DONE**.
# - **ALWAYS**, as part of your "Final Answer", explain how you got
# to the answer on a section that starts with: "\n\nExplanation:\n".
# In the explanation, mention the column names that you used to get
# to the final answer.
# """

# QUESTION = "How may patients were hospitalized during July 2020"
# "in Texas, and nationwide as the total of all states?"
# "Use the hospitalizedIncrease column"
# Out:
# 'Use the hospitalizedIncrease column'

# %%
def create_pandas_dataframe_agent(model, tokenizer, df, verbose=False):
    def query_agent(query, max_length=300): # Add max_length here with a default value
        # Convert query to input format
        inputs = tokenizer(query, return_tensors="pt")

        # Generate response
        # Use max_length here
        outputs = model.generate(inputs["input_ids"], max_length=max_length)
        response = tokenizer.decode(outputs[0], skip_special_tokens=True)

        if verbose:
            print(f"Query: {query}")
            print(f"Response: {response}")

        return response

    return query_agent

# %%
print( response)
print(df.head())
# Out:
# tell me the detail on this dataset.
#
# The first thing I noticed was that the data was not very consistent across the different datasets. I was able to see that the data was not very consistent across the different datasets. I was able to see
#    ID                          Task  ... Efficiency Score User Satisfaction
# 0   1  Gesture-based Control System  ...            75.05                 2
# 1   2    Automated Content Creation  ...            82.12                 5
# 2   3  Gesture-based Control System  ...            25.03                 2
# 3   4  Gesture-based Control System  ...            96.61                 1
# 4   5    Automated Content Creation  ...            66.47                 4
#
# [5 rows x 12 columns]

# %%
df
# Out:
#             ID                            Task  ... Efficiency Score User Satisfaction
# 0            1    Gesture-based Control System  ...            75.05                 2
# 1            2      Automated Content Creation  ...            82.12                 5
# 2            3    Gesture-based Control System  ...            25.03                 2
# 3            4    Gesture-based Control System  ...            96.61                 1
# 4            5      Automated Content Creation  ...            66.47                 4
# ...        ...                             ...  ...              ...               ...
# 499995  499996      Automated Content Creation  ...             8.37                10
# 499996  499997      Automated Content Creation  ...            85.96                 7
# 499997  499998    Gesture-based Control System  ...            95.13                 3
# 499998  499999      Automated Content Creation  ...            18.59                 6
# ...

# %%
import os
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cpu device

# %%
import torch
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda

# %%
target_transform = Lambda(lambda y: torch.zeros(
    10, dtype=torch.float).scatter_(dim=0, index=torch.tensor(y), value=1))

# %%
print(target_transform)
# Out:
# Lambda()
